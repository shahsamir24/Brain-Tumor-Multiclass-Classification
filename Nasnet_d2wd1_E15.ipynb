jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0051.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0052.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0058.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0059.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0060.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0061.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0062.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0063.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0064.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0070.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0071.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0072.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0073.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0074.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0075.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0076.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0082.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0083.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0084.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0085.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0086.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0087.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0088.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0094.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0095.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0096.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0097.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0098.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0099.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0100.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0106.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0107.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0108.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0109.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0110.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0111.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0112.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0118.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0119.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0120.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0121.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0122.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0123.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0124.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0130.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0131.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0132.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0133.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0134.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0135.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0136.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0142.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0143.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0144.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0145.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0146.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0147.jpg
#   inflating: d2 with d1/Training/pituitary_tumor/Tr-pi_0148.jpg

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from sklearn.ensemble import GradientBoostingClassifier
import seaborn as sns
from tqdm import tqdm
from warnings import filterwarnings
import pickle
import os
import shutil
import random
import cv2

# Import sklearn modules
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, roc_auc_score, average_precision_score

# Import tf modules
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import NASNetLarge

filterwarnings("ignore")
np.random.seed(0)

# %%
train_img = []
train_labels_not_encoded = []

test_img = []
test_labels_not_encoded = []

path_train = '/content/d2 with d1/Training/'  # Update the path to the Training directory in session storage
path_test = '/content/d2 with d1/Testing/'  # Update the path to the Testing directory in session storage

img_size = 180
for i in os.listdir(path_train):
    for j in tqdm(os.listdir(path_train + i)):
        train_img.append(cv2.resize(cv2.imread(path_train + i + '/' + j), (img_size, img_size)))
        train_labels_not_encoded.append(i)

for i in os.listdir(path_test):
    for j in tqdm(os.listdir(path_test + i)):
        test_img.append(cv2.resize(cv2.imread(path_test + i + '/' + j), (img_size, img_size)))
        test_labels_not_encoded.append(i)

train_img = np.array(train_img)
test_img = np.array(test_img)
# Out:
# 100%|██████████| 900/900 [00:01<00:00, 514.08it/s]
# 100%|██████████| 900/900 [00:02<00:00, 351.64it/s]
# 100%|██████████| 900/900 [00:03<00:00, 237.57it/s]
# 100%|██████████| 826/826 [00:02<00:00, 344.03it/s]
# 100%|██████████| 149/149 [00:00<00:00, 1154.46it/s]
# 100%|██████████| 150/150 [00:00<00:00, 278.61it/s]
# 100%|██████████| 150/150 [00:00<00:00, 581.56it/s]
# 100%|██████████| 150/150 [00:00<00:00, 291.36it/s]

# %%
y_train = pd.get_dummies(train_labels_not_encoded)
y_test = pd.get_dummies(test_labels_not_encoded)
labels=y_train.columns

# %%
fig, ax = plt.subplots(1,4,figsize=(20,20))
fig.text(s='Sample Image From Each Label',size=18,fontweight='bold',
         color="black",y=0.61,x=0.4,alpha=0.9)
for count, ele in enumerate(os.listdir(path_train)):
    for j in os.listdir(path_train+ele):
        img= cv2.imread(path_train+ele+'/'+j)
        ax[count].imshow(img)
        ax[count].set_title(ele)
        ax[count].axis('off')
        break

# %%
print("Train size:", train_img.shape[0], "Test size:", test_img.shape[0])
# Out:
# Train size: 3526 Test size: 599

# %%
y_train
# Out:
#       glioma_tumor  meningioma_tumor  no_tumor  pituitary_tumor
# 0            False             False      True            False
# 1            False             False      True            False
# 2            False             False      True            False
# 3            False             False      True            False
# 4            False             False      True            False
# ...            ...               ...       ...              ...
# 3521          True             False     False            False
# 3522          True             False     False            False
# 3523          True             False     False            False
# 3524          True             False     False            False
# 3525          True             False     False            False
#
# [3526 rows x 4 columns]

# %%
def clear_previous_calculations():
    try:
        shutil.rmtree("logs")
    except Exception as e:
        pass

    for i in ["tumor_model.h5", "predictions.pkl"]:
        try:
            os.remove(i)
        except Exception as e:
            pass

# %%
def get_model():
    data_augmentation = Sequential([
        layers.RandomFlip("horizontal_and_vertical", input_shape=(img_size, img_size, 3)),
        layers.RandomRotation(0.3),
        layers.RandomZoom(0.1)
    ])
    nasnet = NASNetLarge(include_top=False, input_shape=(img_size, img_size, 3))
    model = Sequential([
        data_augmentation,
        nasnet,
        layers.GlobalAveragePooling2D(),
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(4, activation='softmax')
    ])
    return model

# %%
def get_callbacks():
    tensorboard = TensorBoard(log_dir = 'logs', histogram_freq=1)
    checkpoint = ModelCheckpoint("effnet.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
    reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 2,
                                  mode='auto',verbose=1, min_lr=0.000001)
    return [tensorboard,checkpoint,reduce_lr]

# %%
def get_fig_and_axes_list(plot_count,column_number=2):
    """
    This function takes in the number of subplots to be plotted and the desired number of columns for the subplot grid.
    It then calculates the number of rows required and generates a matplotlib figure with the given number of subplots
    in a grid with the desired number of columns.

    Args:
    - plot_count: int, the number of subplots to be plotted
    - column_number: int, the number of columns in the subplot grid. Default value is 2.

    Returns:
    - fig: matplotlib Figure object, the generated figure
    - axes_list: list of matplotlib Axes objects, the axes of the subplots in the figure
    """
    reminder_num = plot_count % column_number
    row_num = (plot_count // column_number) + (reminder_num > 0)
    axes_list = []
    row_number_alignment = np.ones((row_num, column_number), dtype="int")
    if reminder_num != 0:
        row_number_alignment[-1,-(column_number - reminder_num):] = 0
    coefficient = (3.5 if plot_count==1 else 5.2)
    col_size = coefficient*column_number
    row_size = coefficient*row_num
    fig = plt.figure(figsize=(col_size, row_size), layout="constrained")
    spec = fig.add_gridspec(row_num, column_number)
    for i in range(row_number_alignment.shape[0]):
        for j in range(row_number_alignment.shape[1]):
            if row_number_alignment[i,j] == 1:
                ax = fig.add_subplot(spec[i,j])
                axes_list.append(ax)
    return fig,axes_list

# %%
def get_axes_list(length, column_number=2):
    fig, axes_list = get_fig_and_axes_list(length, column_number=column_number )
    return axes_list

# %%
colors_dark = ["#1F1F1F", "#313131", '#636363', '#AEAEAE', '#DADADA']
colors_red = ["#331313", "#582626", '#9E1717', '#D35151', '#E9B4B4']
colors_green = ['#01411C','#4B6F44','#4F7942','#74C365','#D0F0C0']

sns.palplot(colors_dark)
sns.palplot(colors_green)
sns.palplot(colors_red)

# %%
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR) #Supress warnings
clear_previous_calculations()
model = get_model()
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
print(model.summary())
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-large-no-top.h5
# 343610240/343610240 [==============================] - 2s 0us/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 180, 180, 3)       0
#
#  NASNet (Functional)         (None, 6, 6, 4032)        84916818
#
#  global_average_pooling2d (  (None, 4032)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               1032448
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 85950294 (327.87 MB)
# Trainable params: 85753626 (327.12 MB)
# Non-trainable params: 196668 (768.23 KB)
# _________________________________________________________________
# None

# %%
epochs = 15
batch_size=32
all_callbacks = get_callbacks()
history = model.fit(train_img, y_train, validation_split=0.1,  epochs=epochs, batch_size=batch_size,
                    callbacks=all_callbacks,  shuffle=True, verbose=1, workers=1)
model.load_weights('effnet.h5')
# Out:
# Epoch 1/15
# 100/100 [==============================] - ETA: 0s - loss: 0.7377 - accuracy: 0.7457
# Epoch 1: val_accuracy improved from -inf to 0.81586, saving model to effnet.h5
# 100/100 [==============================] - 365s 2s/step - loss: 0.7377 - accuracy: 0.7457 - val_loss: 49.0946 - val_accuracy: 0.8159 - lr: 0.0010
# Epoch 2/15
# 100/100 [==============================] - ETA: 0s - loss: 0.4657 - accuracy: 0.8569
# Epoch 2: val_accuracy did not improve from 0.81586
# 100/100 [==============================] - 143s 1s/step - loss: 0.4657 - accuracy: 0.8569 - val_loss: 168360.4688 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 3/15
# 100/100 [==============================] - ETA: 0s - loss: 0.4322 - accuracy: 0.8714
# Epoch 3: val_accuracy did not improve from 0.81586
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 100/100 [==============================] - 143s 1s/step - loss: 0.4322 - accuracy: 0.8714 - val_loss: 1994929.8750 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 4/15
# 100/100 [==============================] - ETA: 0s - loss: 0.2714 - accuracy: 0.9146
# Epoch 4: val_accuracy did not improve from 0.81586
# 100/100 [==============================] - 142s 1s/step - loss: 0.2714 - accuracy: 0.9146 - val_loss: 44116.5391 - val_accuracy: 0.0000e+00 - lr: 3.0000e-04
# Epoch 5/15
# 100/100 [==============================] - ETA: 0s - loss: 0.2284 - accuracy: 0.9303
# Epoch 5: val_accuracy did not improve from 0.81586
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 100/100 [==============================] - 141s 1s/step - loss: 0.2284 - accuracy: 0.9303 - val_loss: 13755.8232 - val_accuracy: 0.0000e+00 - lr: 3.0000e-04
# Epoch 6/15
# 100/100 [==============================] - ETA: 0s - loss: 0.1527 - accuracy: 0.9534
# Epoch 6: val_accuracy did not improve from 0.81586
# 100/100 [==============================] - 143s 1s/step - loss: 0.1527 - accuracy: 0.9534 - val_loss: 10685.6309 - val_accuracy: 0.0000e+00 - lr: 9.0000e-05
# Epoch 7/15
# 100/100 [==============================] - ETA: 0s - loss: 0.1305 - accuracy: 0.9600
# Epoch 7: val_accuracy did not improve from 0.81586
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 100/100 [==============================] - 144s 1s/step - loss: 0.1305 - accuracy: 0.9600 - val_loss: 2344.7520 - val_accuracy: 0.0000e+00 - lr: 9.0000e-05
# Epoch 8/15
# 100/100 [==============================] - ETA: 0s - loss: 0.1206 - accuracy: 0.9631
# Epoch 8: val_accuracy did not improve from 0.81586
# 100/100 [==============================] - 140s 1s/step - loss: 0.1206 - accuracy: 0.9631 - val_loss: 1366.3630 - val_accuracy: 0.0000e+00 - lr: 2.7000e-05
# Epoch 9/15
# 100/100 [==============================] - ETA: 0s - loss: 0.1230 - accuracy: 0.9628
# Epoch 9: val_accuracy did not improve from 0.81586
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 100/100 [==============================] - 141s 1s/step - loss: 0.1230 - accuracy: 0.9628 - val_loss: 883.5440 - val_accuracy: 0.0000e+00 - lr: 2.7000e-05
# Epoch 10/15
# 100/100 [==============================] - ETA: 0s - loss: 0.1203 - accuracy: 0.9653
# Epoch 10: val_accuracy did not improve from 0.81586
# 100/100 [==============================] - 143s 1s/step - loss: 0.1203 - accuracy: 0.9653 - val_loss: 589.0305 - val_accuracy: 0.0000e+00 - lr: 8.1000e-06
# Epoch 11/15
# 100/100 [==============================] - ETA: 0s - loss: 0.1102 - accuracy: 0.9679
# Epoch 11: val_accuracy did not improve from 0.81586
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 100/100 [==============================] - 141s 1s/step - loss: 0.1102 - accuracy: 0.9679 - val_loss: 470.0907 - val_accuracy: 0.0000e+00 - lr: 8.1000e-06
# Epoch 12/15
# 100/100 [==============================] - ETA: 0s - loss: 0.1100 - accuracy: 0.9660
# Epoch 12: val_accuracy did not improve from 0.81586
# 100/100 [==============================] - 142s 1s/step - loss: 0.1100 - accuracy: 0.9660 - val_loss: 342.9509 - val_accuracy: 0.0000e+00 - lr: 2.4300e-06
# Epoch 13/15
# 100/100 [==============================] - ETA: 0s - loss: 0.1092 - accuracy: 0.9647
# Epoch 13: val_accuracy did not improve from 0.81586
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1e-06.
# 100/100 [==============================] - 141s 1s/step - loss: 0.1092 - accuracy: 0.9647 - val_loss: 259.4667 - val_accuracy: 0.0028 - lr: 2.4300e-06
# Epoch 14/15
# 100/100 [==============================] - ETA: 0s - loss: 0.1082 - accuracy: 0.9694
# Epoch 14: val_accuracy did not improve from 0.81586
# 100/100 [==============================] - 141s 1s/step - loss: 0.1082 - accuracy: 0.9694 - val_loss: 200.7153 - val_accuracy: 0.0085 - lr: 1.0000e-06
# Epoch 15/15
# 100/100 [==============================] - ETA: 0s - loss: 0.1015 - accuracy: 0.9685
# Epoch 15: val_accuracy did not improve from 0.81586
# 100/100 [==============================] - 143s 1s/step - loss: 0.1015 - accuracy: 0.9685 - val_loss: 157.7050 - val_accuracy: 0.0113 - lr: 1.0000e-06

# %%
fig, ax = plt.subplots(1,2,figsize=(14,7))
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
epochs_count = [i for i in range(len(train_acc))]

fig.text(s='Epochs vs. Training and Validation Accuracy/Loss', size=18, fontweight='bold',
         fontname='monospace', color=colors_dark[1], y=1, x=0.28, alpha=0.8)

sns.despine()
ax[0].plot(epochs_count, train_acc, marker='o',markerfacecolor=colors_green[2], color=colors_green[3],
           label = 'Training Accuracy')
ax[0].plot(epochs_count, val_acc, marker='o',markerfacecolor=colors_red[2], color=colors_red[3],
           label = 'Validation Accuracy')
ax[0].legend(frameon=False)
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')

sns.despine()
ax[1].plot(epochs_count, train_loss, marker='o', markerfacecolor=colors_green[2], color=colors_green[3],
           label='Training Loss')
ax[1].plot(epochs_count, val_loss, marker='o', markerfacecolor=colors_red[2], color=colors_red[3],
           label='Validation Loss')
ax[1].legend(frameon=False)
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Training & Validation Loss')

fig.show()

# %%
pred_prob = model.predict(test_img)
pred = np.argmax(pred_prob,axis=1)
y_test_encoded = np.argmax(y_test.to_numpy(),axis=1)
y_train_encoded = np.argmax(y_train.to_numpy(),axis=1)
train_pred_proba = model.predict(train_img)
train_pred = np.argmax(train_pred_proba,axis=1)
# Out:
# 19/19 [==============================] - 13s 359ms/step
# 111/111 [==============================] - 30s 273ms/step

# %%
boosting_model = GradientBoostingClassifier()
boosting_model.fit(train_pred_proba,  y_train_encoded)
meta_test = boosting_model.predict(pred_prob)

# %%
axes = get_axes_list(3)

axes[0].set_title("Before meta classifier")
ConfusionMatrixDisplay.from_predictions(y_test_encoded, pred, display_labels=labels,
                                        cmap='Blues', ax=axes[0], xticks_rotation="vertical")

axes[1].set_title("After meta classifier")
ConfusionMatrixDisplay.from_predictions(y_test_encoded, meta_test, display_labels=labels,
                                        cmap='Blues', ax=axes[1], xticks_rotation="vertical")

axes[2].set_title("On Train Set")
ConfusionMatrixDisplay.from_predictions(y_train_encoded, train_pred, display_labels=labels,
                                        cmap='Blues', ax=axes[2], xticks_rotation="vertical")

# %%
before = roc_auc_score(y_test, pred_prob,multi_class="ovo")
print("Before meta classifier:\n", classification_report(y_test_encoded,pred),"\n RUC-AUC:", before)
# Out:
# Before meta classifier:
#                precision    recall  f1-score   support
#
#            0       0.27      0.85      0.41       150
#            1       0.10      0.08      0.09       150
#            2       0.00      0.00      0.00       149
#            3       0.00      0.00      0.00       150
#
#     accuracy                           0.23       599
#    macro avg       0.09      0.23      0.12       599
# weighted avg       0.09      0.23      0.12       599
#
#  RUC-AUC: 0.47623051224944324

# %%
after = roc_auc_score(y_test, boosting_model.predict_proba(pred_prob),multi_class="ovo")
print("After meta classifier:\n", classification_report(y_test_encoded, meta_test),"\n RUC-AUC:", after)
# Out:
# After meta classifier:
#                precision    recall  f1-score   support
#
#            0       1.00      0.03      0.06       150
#            1       0.10      0.09      0.09       150
#            2       0.24      0.76      0.37       149
#            3       0.40      0.01      0.03       150
#
#     accuracy                           0.22       599
#    macro avg       0.44      0.22      0.14       599
# weighted avg       0.44      0.22      0.14       599
#
#  RUC-AUC: 0.47683150393035145

# %%
fig,ax_list = get_fig_and_axes_list(10,5)
random_image_index = np.random.randint(test_img.shape[0], size=10)
for count, ele in enumerate(random_image_index):
    ax_list[count]
    ax_list[count].imshow(test_img[ele])
    color = ("green" if pred[ele] == y_test_encoded[ele] else "red")
    ax_list[count].set_title(f"True: {test_labels_not_encoded[ele]}\nPredicted: { labels[pred[ele]] }", color=color)
    ax_list[count].axis('off')
